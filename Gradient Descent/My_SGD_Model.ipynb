# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import SGDRegressor
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score

# %%
df = pd.read_csv(r"C:\Users\Jeevan\Downloads\house-prices.csv")
df.head()
# Out:
#    Home   Price  SqFt  Bedrooms  Bathrooms  Offers Brick Neighborhood
# 0     1  114300  1790         2          2       2    No         East
# 1     2  114200  2030         4          2       3    No         East
# 2     3  114800  1740         3          2       1    No         East
# 3     4   94700  1980         3          2       3    No         East
# 4     5  119800  2130         3          3       3    No         East

# %%
x = df[['SqFt', 'Bedrooms','Bathrooms','Offers']].values
y = df.Price.values

# %%
np.shape(y)
# Out:
# (128,)

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=2)

# %% [markdown]
# ## Scale the variables

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

x_train_scaled = scaler.fit_transform(x_train)
x_test_scaled = scaler.transform(x_test)

# %%
sgd = SGDRegressor(max_iter=10000, eta0=0.0001,tol=1e-4)

# %%
sgd.fit(x_train_scaled, y_train)
# Out:
# c:\Users\Jeevan\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\linear_model\_stochastic_gradient.py:1608: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# SGDRegressor(eta0=0.0001, max_iter=10000, tol=0.0001)

# %%
y_pred= sgd.predict(x_test_scaled)

# %%
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

# Output the results
print("Mean Squared Error:", mse)
print("R-squared:", r2)
# Out:
# Mean Squared Error: 239233512.3839413
# R-squared: 0.6622387541716455

# %%
x_train_scaled.shape
# Out:
# (102, 4)

# %%
y_pred.shape
# Out:
# (26,)

# %%
x.shape
# Out:
# (128, 4)

# %%
y_test
# Out:
# array([142600, 117500, 102600,  94700, 182000, 156400, 130300, 100900,
#        166500, 157600, 114800, 123600,  69100, 115900, 113500, 176800,
#        114300, 130800, 102500, 140900, 105600, 149300, 123000, 150200,
#        126300, 102700], dtype=int64)

# %%
y_pred
# Out:
# array([134703.34791434, 113139.51008395,  98498.61223866, 115088.7521336 ,
#        153391.10703701, 164436.4111413 , 122101.44839015,  99529.45859782,
#        140856.26938704, 160255.42611547, 129114.1446467 , 116163.96596976,
#         85963.7745887 , 118180.26989363, 122716.95372234, 157468.08236175,
#        108602.82625524, 121137.66390521, 125778.35743501, 125674.34773392,
#        127290.58537792, 155407.41096088, 112635.43410298, 113576.5241907 ,
#        112257.04090288, 107964.62652583])

# %%
df2 = pd.DataFrame({'Actual':y_test, 'Predicted': y_pred})
df2=df2.round()
df2.head()
# Out:
#    Actual  Predicted
# 0  142600   134703.0
# 1  117500   113140.0
# 2  102600    98499.0
# 3   94700   115089.0
# 4  182000   153391.0

# %%
df2['Difference'] = (df2['Actual'] - df2['Predicted']).abs()

# %%
df2.head()
# Out:
#    Actual  Predicted  Difference
# 0  142600   134703.0      7897.0
# 1  117500   113140.0      4360.0
# 2  102600    98499.0      4101.0
# 3   94700   115089.0     20389.0
# 4  182000   153391.0     28609.0

# %%
df2['% Difference'] = ((df2['Difference']/df2['Actual']*100).abs()).round(2).astype(str) + ' %'

df2
# Out:
#     Actual  Predicted  Difference % Difference
# 0   142600   134703.0      7897.0       5.54 %
# 1   117500   113140.0      4360.0       3.71 %
# 2   102600    98499.0      4101.0        4.0 %
# 3    94700   115089.0     20389.0      21.53 %
# 4   182000   153391.0     28609.0      15.72 %
# 5   156400   164436.0      8036.0       5.14 %
# 6   130300   122101.0      8199.0       6.29 %
# 7   100900    99529.0      1371.0       1.36 %
# 8   166500   140856.0     25644.0       15.4 %
# 9   157600   160255.0      2655.0       1.68 %
# 10  114800   129114.0     14314.0      12.47 %
# 11  123600   116164.0      7436.0       6.02 %
# 12   69100    85964.0     16864.0      24.41 %
# 13  115900   118180.0      2280.0       1.97 %
# 14  113500   122717.0      9217.0       8.12 %
# 15  176800   157468.0     19332.0      10.93 %
# 16  114300   108603.0      5697.0       4.98 %
# 17  130800   121138.0      9662.0       7.39 %
# 18  102500   125778.0     23278.0      22.71 %
# 19  140900   125674.0     15226.0      10.81 %
# 20  105600   127291.0     21691.0      20.54 %
# 21  149300   155407.0      6107.0       4.09 %
# 22  123000   112635.0     10365.0       8.43 %
# 23  150200   113577.0     36623.0      24.38 %
# 24  126300   112257.0     14043.0      11.12 %
# 25  102700   107965.0      5265.0       5.13 %
