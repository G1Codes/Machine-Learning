# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score

# %%
df = pd.read_csv(r"C:\Users\Jeevan\Downloads\house-prices.csv")
df.head()
# Out:
#    Home   Price  SqFt  Bedrooms  Bathrooms  Offers Brick Neighborhood
# 0     1  114300  1790         2          2       2    No         East
# 1     2  114200  2030         4          2       3    No         East
# 2     3  114800  1740         3          2       1    No         East
# 3     4   94700  1980         3          2       3    No         East
# 4     5  119800  2130         3          3       3    No         East

# %%
x = df[['SqFt', 'Bedrooms','Bathrooms','Offers']].values
y = df.Price.values

# %%
np.shape(y)
# Out:
# (128,)

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=2)

# %% [markdown]
# ## Scale the variables

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

x_train_scaled = scaler.fit_transform(x_train)
x_test_scaled = scaler.transform(x_test)

# %%
lr = LinearRegression()

# %%
lr.fit(x_train_scaled, y_train)
# Out:
# LinearRegression()

# %%
y_pred= lr.predict(x_test_scaled)

# %%
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

# Output the results
print("Mean Squared Error:", mse)
print("R-squared:", r2)
# Out:
# Mean Squared Error: 225893547.39851052
# R-squared: 0.6810727509135174

# %%
x_train_scaled.shape
# Out:
# (102, 4)

# %%
y_pred.shape
# Out:
# (26,)

# %%
x.shape
# Out:
# (128, 4)

# %%
y_test
# Out:
# array([142600, 117500, 102600,  94700, 182000, 156400, 130300, 100900,
#        166500, 157600, 114800, 123600,  69100, 115900, 113500, 176800,
#        114300, 130800, 102500, 140900, 105600, 149300, 123000, 150200,
#        126300, 102700], dtype=int64)

# %%
y_pred
# Out:
# array([138255.53260487, 115817.92888714,  99294.01424145, 117072.58335723,
#        155253.82659569, 166791.03213641, 124070.6153888 , 100498.21829379,
#        142083.84166411, 164286.7882223 , 131068.64742037, 119222.309019  ,
#         86124.02930986, 121491.89577357, 126598.46597135, 160738.52171426,
#        110711.35868936, 123881.34362094, 126007.46261426, 128987.91381873,
#        127709.65268018, 157523.41335026, 115250.5321985 , 115370.3932913 ,
#        112578.79523976, 108114.09743174])

# %%
df2 = pd.DataFrame({'Actual':y_test, 'Predicted': y_pred})
df2=df2.round()
df2.head()
# Out:
#    Actual  Predicted
# 0  142600   138256.0
# 1  117500   115818.0
# 2  102600    99294.0
# 3   94700   117073.0
# 4  182000   155254.0

# %%
df2['Difference'] = (df2['Actual'] - df2['Predicted']).abs()

# %%
df2.head()
# Out:
#    Actual  Predicted  Difference
# 0  142600   138256.0      4344.0
# 1  117500   115818.0      1682.0
# 2  102600    99294.0      3306.0
# 3   94700   117073.0     22373.0
# 4  182000   155254.0     26746.0

# %%
df2['% Difference'] = ((df2['Difference']/df2['Actual']*100).abs()).round(2).astype(str) + ' %'

df2
# Out:
#     Actual  Predicted  Difference % Difference
# 0   142600   138256.0      4344.0       3.05 %
# 1   117500   115818.0      1682.0       1.43 %
# 2   102600    99294.0      3306.0       3.22 %
# 3    94700   117073.0     22373.0      23.63 %
# 4   182000   155254.0     26746.0       14.7 %
# 5   156400   166791.0     10391.0       6.64 %
# 6   130300   124071.0      6229.0       4.78 %
# 7   100900   100498.0       402.0        0.4 %
# 8   166500   142084.0     24416.0      14.66 %
# 9   157600   164287.0      6687.0       4.24 %
# 10  114800   131069.0     16269.0      14.17 %
# 11  123600   119222.0      4378.0       3.54 %
# 12   69100    86124.0     17024.0      24.64 %
# 13  115900   121492.0      5592.0       4.82 %
# 14  113500   126598.0     13098.0      11.54 %
# 15  176800   160739.0     16061.0       9.08 %
# 16  114300   110711.0      3589.0       3.14 %
# 17  130800   123881.0      6919.0       5.29 %
# 18  102500   126007.0     23507.0      22.93 %
# ...

# %%
# Check the data type of the '% Difference' column
print("Data typy", df2['% Difference'].dtype)

# Convert the '% Difference' column to numeric values (removing the '%' sign)
df2['% Difference'] = df2['% Difference'].str.rstrip(' %').astype(float)

# Calculate the mean of the '% Difference' column
mean_difference = df2['% Difference'].mean()
mean_difference
# Out:
# object
# 9.862307692307693
